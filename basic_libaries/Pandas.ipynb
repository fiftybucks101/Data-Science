# %% [markdown]
# <a href="https://colab.research.google.com/github/fiftybucks101/Data-Science_2024/blob/main/basic_libaries/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ***Series*** : A one-dimensional labeled array
#
# ***Dataframe***: A two dimensional data structure that
#            holds data like a two-dimension array or a table with rows and columns.

# %%
s = pd.Series([1,3,4, np.nan, 9])
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    9.0
# dtype: float64

# %%
data = {
    'apples':[3,2,0,1],
    'oranges':[0,3,7,2]
}

purchases = pd.DataFrame(data)

purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data,index = ['Riped','Big','Expensive','Rotten'])

# %%
purchases
# Out:
#            apples  oranges
# Riped           3        0
# Big             2        3
# Expensive       0        7
# Rotten          1        2

# %%
dates = pd.date_range("20130101", periods = 5)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randint(1,100,size=(5,4)),index = dates, columns=list("WXYZ"))

df
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92

# %% [markdown]
# Locate Function

# %%
df.loc['2013-01-01':'2013-01-04']
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17

# %% [markdown]
# DataFrame by Passing a Dictionary where
#
# Keys = Column and Values = Rows

# %%
df2 = pd.DataFrame({
    'A':np.arange(3),
    'B':pd.date_range("20021201",periods = 3),
    'C':"Foo Fighters",
    'D':list(["test","train","test"])
})

df2
# Out:
#    A          B             C      D
# 0  0 2002-12-01  Foo Fighters   test
# 1  1 2002-12-02  Foo Fighters  train
# 2  2 2002-12-03  Foo Fighters   test

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C            object
# D            object
# dtype: object

# %%
df2.B
# Out:
# 0   2002-12-01
# 1   2002-12-02
# 2   2002-12-03
# Name: B, dtype: datetime64[ns]

# %%
df.head()
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92

# %%
df.tail(2)
# Out:
#              W   X   Y   Z
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92

# %%
df.head(-2)
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92

# %%
df.to_numpy()
# Out:
# array([[87, 45, 28, 36],
#        [97, 37, 58, 41],
#        [36, 82,  9, 46],
#        [87, 41, 33, 17],
#        [81, 37, 45, 92]])

# %%
df2.to_numpy()
# Out:
# array([[0, Timestamp('2002-12-01 00:00:00'), 'Foo Fighters', 'test'],
#        [1, Timestamp('2002-12-02 00:00:00'), 'Foo Fighters', 'train'],
#        [2, Timestamp('2002-12-03 00:00:00'), 'Foo Fighters', 'test']],
#       dtype=object)

# %%
df.describe()
# Out:
#                W          X          Y          Z
# count   5.000000   5.000000   5.000000   5.000000
# mean   77.600000  48.400000  34.600000  46.400000
# std    23.954123  19.073542  18.420098  27.754279
# min    36.000000  37.000000   9.000000  17.000000
# 25%    81.000000  37.000000  28.000000  36.000000
# 50%    87.000000  41.000000  33.000000  41.000000
# 75%    87.000000  45.000000  45.000000  46.000000
# max    97.000000  82.000000  58.000000  92.000000

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05
# W          87          97          36          87          81
# X          45          37          82          41          37
# Y          28          58           9          33          45
# Z          36          41          46          17          92

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92>

# %%
df
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92

# %%
df.sort_index(axis = 1, ascending= False)
# Out:
#              Z   Y   X   W
# 2013-01-01  36  28  45  87
# 2013-01-02  41  58  37  97
# 2013-01-03  46   9  82  36
# 2013-01-04  17  33  41  87
# 2013-01-05  92  45  37  81

# %%
df.sort_values(by="Y", ascending = False)
# Out:
#              W   X   Y   Z
# 2013-01-02  97  37  58  41
# 2013-01-05  81  37  45  92
# 2013-01-04  87  41  33  17
# 2013-01-01  87  45  28  36
# 2013-01-03  36  82   9  46

# %%
df.sort_values(by="Z")
# Out:
#              W   X   Y   Z
# 2013-01-04  87  41  33  17
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-05  81  37  45  92

# %%
df["W"]
# Out:
# 2013-01-01    87
# 2013-01-02    97
# 2013-01-03    36
# 2013-01-04    87
# 2013-01-05    81
# Freq: D, Name: W, dtype: int64

# %%
df.W
# Out:
# 2013-01-01    87
# 2013-01-02    97
# 2013-01-03    36
# 2013-01-04    87
# 2013-01-05    81
# Freq: D, Name: W, dtype: int64

# %%
df[0:3]
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46

# %%
df[1:4]
# Out:
#              W   X   Y   Z
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17

# %%
df.loc[dates[1]]
# Out:
# W    97
# X    37
# Y    58
# Z    41
# Name: 2013-01-02 00:00:00, dtype: int64

# %%
df
# Out:
#              W   X   Y   Z
# 2013-01-01  87  45  28  36
# 2013-01-02  97  37  58  41
# 2013-01-03  36  82   9  46
# 2013-01-04  87  41  33  17
# 2013-01-05  81  37  45  92

# %%
df.loc["2013-01-03":,["X","Y"]]
# Out:
#              X   Y
# 2013-01-03  82   9
# 2013-01-04  41  33
# 2013-01-05  37  45

# %%
df.at[dates[1],"X"]
# Out:
# 37

# %%
pd.read_csv("/home/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
