# %% [markdown]
# <a href="https://colab.research.google.com/github/fiftybucks101/Data-Science_2024/blob/main/basic_EDA/IPL_auction_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/iplauction2023.csv')

df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis',linewidths=0)

plt.tight_layout()

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df['nationality'].nunique()
# Out:
# 14

# %%
df.groupby('nationality')['nationality'].count()
# Out:
# nationality
# Afghanistan       7
# Australia        14
# Bangladesh        4
# England          24
# India           201
# Ireland           2
# Namibia           1
# Netherlands       1
# New Zealand      11
# Singapore         1
# South Africa     19
# Sri Lanka         8
# West Indies      14
# Zimbabwe          2
# Name: nationality, dtype: int64

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(15,7))
sns.countplot(data=df, x='nationality')
# Out:
# <Axes: xlabel='nationality', ylabel='count'>

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
sns.countplot(data=df,x='player style')
# Out:
# <Axes: xlabel='player style', ylabel='count'>

# %%
sns.displot(data=df,x='final price (in lacs)',aspect = 2)
plt.xticks(np.arange(0,1750,100),rotation = 45)
# Out:
# ([<matplotlib.axis.XTick at 0x7810235533a0>,
# ...
#  [Text(0, 0, '0'),
#   Text(100, 0, '100'),
#   Text(200, 0, '200'),
#   Text(300, 0, '300'),
#   Text(400, 0, '400'),
#   Text(500, 0, '500'),
#   Text(600, 0, '600'),
#   Text(700, 0, '700'),
#   Text(800, 0, '800'),
#   Text(900, 0, '900'),
#   Text(1000, 0, '1000'),
#   Text(1100, 0, '1100'),
#   Text(1200, 0, '1200'),
#   Text(1300, 0, '1300'),
#   Text(1400, 0, '1400'),
#   Text(1500, 0, '1500'),
#   Text(1600, 0, '1600'),
#   Text(1700, 0, '1700')])

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
sns.countplot(data=df,x='franchise')
# Out:
# <Axes: xlabel='franchise', ylabel='count'>

# %%
plt.figure(figsize=(11,6))
sns.countplot(data=df,x='status',hue='franchise')
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.dropna(subset=['final price (in lacs)'],inplace=True)

# %%
df.head()
# Out:
#               name player style  nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler        India                   NaN
# 3  Shakib Al Hasan   Allrounder   Bangladesh                 150.0
# 4         Joe Root       Batter      England                 100.0
# 5     Abdul Basith   Allrounder        India                  20.0
# 7     Akeal Hosein       Bowler  West Indies                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD
# 5                   20.0        RR      SOLD
# 7                  100.0       SRH      SOLD

# %%
sns.heatmap(df.isna(),yticklabels=False,cbar=False,cmap='magma')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   238 non-null    object
#  1   player style           238 non-null    object
#  2   nationality            238 non-null    object
#  3   base price (in lacs)   80 non-null     float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 238 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 14.9+ KB

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index             name player style  nationality  base price (in lacs)  \
# 0      0     Harshit Rana       Bowler        India                   NaN
# 1      3  Shakib Al Hasan   Allrounder   Bangladesh                 150.0
# 2      4         Joe Root       Batter      England                 100.0
# 3      5     Abdul Basith   Allrounder        India                  20.0
# 4      7     Akeal Hosein       Bowler  West Indies                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                  150.0       KKR      SOLD
# 2                  100.0        RR      SOLD
# 3                   20.0        RR      SOLD
# 4                  100.0       SRH      SOLD

# %%
df.drop(columns='index',inplace=True)

# %%
df.head()
# Out:
#               name player style  nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler        India                   NaN
# 1  Shakib Al Hasan   Allrounder   Bangladesh                 150.0
# 2         Joe Root       Batter      England                 100.0
# 3     Abdul Basith   Allrounder        India                  20.0
# 4     Akeal Hosein       Bowler  West Indies                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                  150.0       KKR      SOLD
# 2                  100.0        RR      SOLD
# 3                   20.0        RR      SOLD
# 4                  100.0       SRH      SOLD

# %%
df.sort_values(by='final price (in lacs)', ascending = False).iloc[0:20]
# Out:
#                  name player style  nationality  base price (in lacs)  \
# 79         Sam Curran   Allrounder      England                 200.0
# 77      Cameron Green   Allrounder    Australia                 200.0
# 221          KL Rahul    WK-Batter        India                   NaN
# 76         Ben Stokes   Allrounder      England                 200.0
# 225   Ravindra Jadeja   Allrounder        India                   NaN
# 70    Nicholas Pooran    WK-Batter  West Indies                 200.0
# 219      Rohit Sharma       Batter        India                   NaN
# 236      Rishabh Pant    WK-Batter        India                   NaN
# 159      Ishan Kishan    WK-Batter        India                   NaN
# 230     Hardik Pandya   Allrounder        India                   NaN
# 211       Virat Kohli       Batter        India                   NaN
# 229       Rashid Khan       Bowler  Afghanistan                   NaN
# ...

# %%
sns.set_style()
plt.figure(figsize=(15,10))
sns.catplot(data = df,x='franchise', y = 'final price (in lacs)',aspect=2,hue='player style',col='status')
